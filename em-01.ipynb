# %% [markdown]
# #Q20: WHY IS AN OCCUPATION REQUIRED HERE
# -----
# Occupation is required so that the company can know about the type of user basse it has, which will allow it to make better decisions in the future, because who are buying the product matter a lot. Different people have different income brackets, likes and hates and different priorities. It would help them to refine the product more according to the user base.

# %% [markdown]
# #Q3: WHY NOT A DICHOTONOMOUS SCALE
# ----
# Dichotonoumous scale would not be so precise with the level of answering the questions, altough the data obtained would be simpler and simpler to process. But by having varying degrees of possibilities for the answer, more refined and detailed data about the user likes and dislikes, and product usage could be obtained. It would give a very good idea ofm how the users might weigh the usage of product and to what degree.

# %% [markdown]
# #Q11: WHY NOT AN OPEN-ENDED SCALE
# ----
# An open-ended scale would mean lot of randomness in the data, because one is allowed to enter any value. It would make the data processing very difficult, and with these given ranges only the company would be able to get a really solid idea about the spenings of it's users. It would make data processing much easier, avoid information which would take up processing resources but not really produce much benefit for the company.
